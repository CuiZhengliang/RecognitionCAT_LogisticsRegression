# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
import scipy
from PIL import Image
from scipy import ndimage
from lr_utils import load_dataset

# %%
# Loading the data (cat/non-cat)
train_set_x_orig, train_set_y, test_set_x_orig, test_set_y, classes = load_dataset()

# %%
def sigmoid(z):
    s = 1.0 / (1 + np.exp(-z))
    return s

# %%
def initialize_with_zeros(dim):
    # dim means the number of parameters in this case
    w = np.zeros((dim, 1))
    b = 0
    assert (w.shape == (dim, 1))
    assert (isinstance(b, int) or isinstance(b, float))
    return w, b

# %%
def propagate(w, b, X, Y):
    m = X.shape[1]

    # FORWARD PROPAGATION (FROM X TO COST)
    A = sigmoid(np.dot(w.T, X) + b)
    cost = -(1.0/m) * np.sum((Y*np.log(A) + (1-Y)*np.log(1-A)))

    # BACKWARD PROPAGATION (TO FIND GRAD)
    dw = (1.0/m) * np.dot(X, (A-Y).T)
    db = (1.0/m) * np.sum(A-Y)
    assert(dw.shape == w.shape)
    assert(db.dtype == float)
    cost = np.squeeze(cost)
    assert (cost.shape == ())

    # dictionary
    grads = {"dw": dw,
             "db": db}

    return grads, cost

# %%
def optimize(w, b, X, Y, num_iterations, learning_rate, print_cost = False):
    costs = []

    for i in range(num_iterations):
        # Cost and gradient calculation
        grads, cost = propagate(w, b, X, Y)

        # Retrieve derivatives from grads
        dw = grads["dw"]
        db = grads["db"]

        # update rule
        w = w - learning_rate*dw
        b = b - learning_rate*db

        # Record the costs
        if i % 100 == 0:
            costs.append(cost)

        # Print the cost every 100 training examples
        if print_cost and i % 100 == 0:
            print ("Cost after iteration %i: %f" %(i, cost))

    params = {"w": w,
              "b": b}

    grads = {"dw": dw,
             "db": db}

    return params, grads, costs

# %%
def predict(w, b, X):
    m = X.shape[1]
    Y_prediction = np.zeros((1,m))
    w = w.reshape(X.shape[0], 1)

    # Compute vector "A" predicting the probabilities of a cat being present in the picture
    A = sigmoid(np.dot(w.T, X) + b)

    for i in range(A.shape[1]):
        # Convert probabilities A[0,i] to actual predictions p[0,i]
        if A[0,i] > 0.5:
            Y_prediction[0,i] = 1
        else:
            Y_prediction[0,i] = 0

    assert(Y_prediction.shape == (1, m))

    return Y_prediction

# %%
# GRADED FUNCTION: model
def model(X_train, Y_train, X_test, Y_test, num_iterations = 2000, learning_rate = 0.5, print_cost = False):
    # initialize parameters with zeros
    w, b = initialize_with_zeros(X_train.shape[0])

    # Gradient descent (≈ 1 line of code)
    parameters, grads, costs = optimize(w, b, X_train, Y_train, num_iterations, learning_rate, print_cost)

    # Retrieve parameters w and b from dictionary "parameters"
    w = parameters["w"]
    b = parameters["b"]

    # Predict test/train set examples (≈ 2 lines of code)
    Y_prediction_test = predict(w, b, X_test)
    Y_prediction_train = predict(w, b, X_train)

    ### END CODE HERE ###

    # Print train/test Errors
    print("train accuracy: {} %".format(100 - np.mean(np.abs(Y_prediction_train - Y_train)) * 100))
    print("test accuracy: {} %".format(100 - np.mean(np.abs(Y_prediction_test - Y_test)) * 100))

    d = {"costs": costs,
         "Y_prediction_test": Y_prediction_test,
         "Y_prediction_train" : Y_prediction_train,
         "w" : w,
         "b" : b,
         "learning_rate" : learning_rate,
         "num_iterations": num_iterations}

    return d

# %%
m_train = train_set_x_orig.shape[0]
m_test = test_set_x_orig.shape[0]
num_px = train_set_x_orig.shape[1]

# Image2vector
train_set_x_flatten = train_set_x_orig.reshape(m_train, -1).T  #原始训练集的设为（12288*209）
test_set_x_flatten = test_set_x_orig.reshape(m_test, -1).T  #原始测试集设为（12288*50）

train_set_x = train_set_x_flatten/255.  #将训练集矩阵标准化
test_set_x = test_set_x_flatten/255.  #将测试集矩阵标准化

# %%
d = model(train_set_x, train_set_y, test_set_x, test_set_y,
          num_iterations = 6000, learning_rate = 0.006, print_cost = True)
# Out:
# Cost after iteration 0: 0.693147
# Cost after iteration 100: 0.649811
# Cost after iteration 200: 0.538312
# Cost after iteration 300: 0.439262
# Cost after iteration 400: 0.349825
# Cost after iteration 500: 0.278498
# Cost after iteration 600: 0.249764
# Cost after iteration 700: 0.231178
# Cost after iteration 800: 0.215229
# Cost after iteration 900: 0.201339
# Cost after iteration 1000: 0.189110
# Cost after iteration 1100: 0.178249
# Cost after iteration 1200: 0.168533
# Cost after iteration 1300: 0.159788
# Cost after iteration 1400: 0.151873
# Cost after iteration 1500: 0.144677
# Cost after iteration 1600: 0.138104
# Cost after iteration 1700: 0.132079
# Cost after iteration 1800: 0.126537
# Cost after iteration 1900: 0.121421
# Cost after iteration 2000: 0.116687
# Cost after iteration 2100: 0.112292
# Cost after iteration 2200: 0.108203
# Cost after iteration 2300: 0.104389
# Cost after iteration 2400: 0.100823
# Cost after iteration 2500: 0.097484
# Cost after iteration 2600: 0.094349
# Cost after iteration 2700: 0.091402
# Cost after iteration 2800: 0.088626
# Cost after iteration 2900: 0.086007
# Cost after iteration 3000: 0.083532
# Cost after iteration 3100: 0.081190
# Cost after iteration 3200: 0.078970
# Cost after iteration 3300: 0.076865
# Cost after iteration 3400: 0.074864
# Cost after iteration 3500: 0.072960
# Cost after iteration 3600: 0.071148
# Cost after iteration 3700: 0.069420
# Cost after iteration 3800: 0.067770
# Cost after iteration 3900: 0.066195
# Cost after iteration 4000: 0.064688
# Cost after iteration 4100: 0.063246
# Cost after iteration 4200: 0.061864
# Cost after iteration 4300: 0.060539
# Cost after iteration 4400: 0.059268
# Cost after iteration 4500: 0.058046
# Cost after iteration 4600: 0.056873
# Cost after iteration 4700: 0.055744
# Cost after iteration 4800: 0.054658
# Cost after iteration 4900: 0.053611
# Cost after iteration 5000: 0.052603
# Cost after iteration 5100: 0.051630
# Cost after iteration 5200: 0.050692
# Cost after iteration 5300: 0.049786
# Cost after iteration 5400: 0.048910
# Cost after iteration 5500: 0.048064
# Cost after iteration 5600: 0.047246
# Cost after iteration 5700: 0.046454
# Cost after iteration 5800: 0.045687
# Cost after iteration 5900: 0.044944
# train accuracy: 100.0 %
# test accuracy: 70.0 %

# %%
costs = np.squeeze(d['costs'])
plt.plot(costs)
plt.ylabel('cost')
plt.xlabel('iterations (per hundreds)')
plt.title("Learning rate =" + str(d["learning_rate"]))
plt.show()

# %%
learning_rates = [0.01, 0.001, 0.0001]
models = {}
for i in learning_rates:
    print ("学习率: " + str(i))
    models[str(i)] = model(train_set_x, train_set_y, test_set_x, test_set_y,
                           num_iterations = 6000, learning_rate = i, print_cost = False)
    print ('\n' + "-------------------------------------------------------" + '\n')

for i in learning_rates:
    plt.plot(np.squeeze(models[str(i)]["costs"]), label= str(models[str(i)]["learning_rate"]))

plt.ylabel('cost')
plt.xlabel('iterations')

legend = plt.legend(loc='upper center', shadow=True)
frame = legend.get_frame()
frame.set_facecolor('0.90')
plt.show()
# Out:
# 学习率: 0.01
# train accuracy: 100.0 %
# test accuracy: 70.0 %
#
# -------------------------------------------------------
#
# 学习率: 0.001
# train accuracy: 97.12918660287082 %
# test accuracy: 70.0 %
#
# -------------------------------------------------------
#
# 学习率: 0.0001
# train accuracy: 79.42583732057416 %
# test accuracy: 56.0 %
#
# -------------------------------------------------------

# %%
learning_rates = [0.009, 0.005, 0.001]
models = {}
for i in learning_rates:
    print ("学习率: " + str(i))
    models[str(i)] = model(train_set_x, train_set_y, test_set_x, test_set_y,
                           num_iterations = 6000, learning_rate = i, print_cost = False)
    print ('\n' + "-------------------------------------------------------" + '\n')

for i in learning_rates:
    plt.plot(np.squeeze(models[str(i)]["costs"]), label= str(models[str(i)]["learning_rate"]))

plt.ylabel('cost')
plt.xlabel('iterations')

legend = plt.legend(loc='upper center', shadow=True)
frame = legend.get_frame()
frame.set_facecolor('0.90')
plt.show()
# Out:
# 学习率: 0.009
# train accuracy: 100.0 %
# test accuracy: 70.0 %
#
# -------------------------------------------------------
#
# 学习率: 0.005
# train accuracy: 100.0 %
# test accuracy: 68.0 %
#
# -------------------------------------------------------
#
# 学习率: 0.001
# train accuracy: 97.12918660287082 %
# test accuracy: 70.0 %
#
# -------------------------------------------------------

# %%
my_image = "WeChat2.jpeg"

# We preprocess the image to fit your algorithm.
fname = "images/" + my_image
image = np.array(ndimage.imread(fname, flatten=False))
my_image = scipy.misc.imresize(image, size=(num_px,num_px)).reshape((1, num_px*num_px*3)).T
my_predicted_image = predict(d["w"], d["b"], my_image)

plt.imshow(image)
plt.show()
print("y = " + str(np.squeeze(my_predicted_image)) + ", 我猜这是一张 \"" + 
      classes[int(np.squeeze(my_predicted_image)),].decode("utf-8") +  "\" 图片.")
# Out:
# y = 1.0, 我猜这是一张 "cat" 图片.
